# %% [markdown]
# <a href="https://colab.research.google.com/github/yeyevtushenko/AI/blob/Lesson13.05.2024/Lesson13_05_2024_AI_H_22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os
import contextlib

# %%
try:
    from surprise import Dataset, SVD, Reader, accuracy
except:
    # !pip install -q surprise
    from surprise import Dataset, SVD, Reader, accuracy

from surprise.model_selection import train_test_split
from surprise.model_selection import cross_validate
from surprise import BaselineOnly, SVD, KNNBasic, CoClustering
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.4/154.4 kB 1.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for scikit-surprise (pyproject.toml) ... done

# %%
try:
    import optuna
except:
    # !pip install -q optuna
    import optuna
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.1/380.1 kB 2.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.4/233.4 kB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 8.4 MB/s eta 0:00:00

# %%
df = pd.read_csv("https://raw.githubusercontent.com/HalyshAnton/IT-Step-Pyton-AI/main/module7/data/ratings.csv")

# %%
df.head()
# Out:
#    user_id  movie_id  rating   timestamp
# 0      172     94969     5.0  1396067836
# 1      172     98956     4.0  1396067879
# 2      176     73881     4.0  1499807147
# 3      221      1900     4.5  1288550866
# 4      333     33688     4.0  1412015122

# %%
df.describe()
# Out:
#              user_id       movie_id        rating     timestamp
# count   17604.000000   17604.000000  17604.000000  1.760400e+04
# mean   141251.609009   88913.605942      3.465945  1.403256e+09
# std     81731.882435   51285.238375      1.203144  1.515083e+08
# min       172.000000     139.000000      0.500000  8.282224e+08
# 25%     71256.000000   55098.000000      3.000000  1.395695e+09
# 50%    138487.000000   89554.000000      3.500000  1.456552e+09
# 75%    210264.500000  134779.500000      4.500000  1.494418e+09
# max    283195.000000  193843.000000      5.000000  1.537934e+09

# %%
df['rating'].describe()
# Out:
# count    17604.000000
# mean         3.465945
# std          1.203144
# min          0.500000
# 25%          3.000000
# 50%          3.500000
# 75%          4.500000
# max          5.000000
# Name: rating, dtype: float64

# %%
reader = Reader(rating_scale=(0, 5))

data = Dataset.load_from_df(df[["user_id", "movie_id", "rating"]], reader)

# %%
trainset, testset = train_test_split(data, train_size=0.8)

# %%
def objective(trial):
    algorithm = trial.suggest_categorical('algorithm', ['KNNBasic', 'SVD', 'BaselineOnly', 'CoClustering'])

    if algorithm == 'KNNBasic':
        k = trial.suggest_int('k', 10, 40)
        min_k = trial.suggest_int('min_k', 1, 10)
        sim_options = {'name': trial.suggest_categorical('similarity', ['cosine', 'msd', 'pearson']),
                       'user_based': trial.suggest_categorical('user_based', [True, False])}
        algo = KNNBasic(k=k, min_k=min_k, sim_options=sim_options)
    elif algorithm == 'SVD':
        n_factors = trial.suggest_int('n_factors', 50, 200)
        n_epochs = trial.suggest_int('n_epochs', 20, 100)
        algo = SVD(n_factors=n_factors, n_epochs=n_epochs)
    elif algorithm == 'BaselineOnly':
        bsl_options = {'method': trial.suggest_categorical('method', ['als', 'sgd']),
                       'reg_u': trial.suggest_loguniform('reg_u', 1e-6, 1e-2),
                       'reg_i': trial.suggest_loguniform('reg_i', 1e-6, 1e-2)}
        algo = BaselineOnly(bsl_options=bsl_options)
    else:
        algo = CoClustering(n_cltr_u=trial.suggest_int('n_cltr_u', 3, 10),
                            n_cltr_i=trial.suggest_int('n_cltr_i', 3, 10))

    results = cross_validate(algo, data, measures=['RMSE'], cv=3, verbose=False)
    rmse_mean = results['test_rmse'].mean()

    return rmse_mean

# %%
study = optuna.create_study(direction='minimize', storage=None, load_if_exists=True)


with open(os.devnull, 'w') as devnull:
    with contextlib.redirect_stdout(devnull):
        study.optimize(objective, n_trials=100)
# Out:
# [I 2024-05-22 06:15:44,013] A new study created in memory with name: no-name-10aacda3-6183-4331-9ad3-0e8b6963677a
# [I 2024-05-22 06:15:50,196] Trial 0 finished with value: 1.178445317142472 and parameters: {'algorithm': 'KNNBasic', 'k': 30, 'min_k': 8, 'similarity': 'cosine', 'user_based': True}. Best is trial 0 with value: 1.178445317142472.
# [I 2024-05-22 06:15:57,454] Trial 1 finished with value: 0.9706626394043433 and parameters: {'algorithm': 'SVD', 'n_factors': 146, 'n_epochs': 81}. Best is trial 1 with value: 0.9706626394043433.
# [I 2024-05-22 06:16:00,947] Trial 2 finished with value: 0.9815211867430597 and parameters: {'algorithm': 'SVD', 'n_factors': 184, 'n_epochs': 52}. Best is trial 1 with value: 0.9706626394043433.
# [I 2024-05-22 06:16:03,776] Trial 3 finished with value: 0.9681354247939034 and parameters: {'algorithm': 'SVD', 'n_factors': 72, 'n_epochs': 98}. Best is trial 3 with value: 0.9681354247939034.
# [I 2024-05-22 06:16:09,039] Trial 4 finished with value: 1.1850726094920245 and parameters: {'algorithm': 'KNNBasic', 'k': 18, 'min_k': 8, 'similarity': 'pearson', 'user_based': True}. Best is trial 3 with value: 0.9681354247939034.
# [I 2024-05-22 06:16:10,682] Trial 5 finished with value: 0.9891773568230514 and parameters: {'algorithm': 'SVD', 'n_factors': 131, 'n_epochs': 22}. Best is trial 3 with value: 0.9681354247939034.
# [I 2024-05-22 06:16:13,567] Trial 6 finished with value: 1.0622395747436741 and parameters: {'algorithm': 'CoClustering', 'n_cltr_u': 10, 'n_cltr_i': 6}. Best is trial 3 with value: 0.9681354247939034.
# <ipython-input-10-b6cb755ede07>:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_u': trial.suggest_loguniform('reg_u', 1e-6, 1e-2),
# <ipython-input-10-b6cb755ede07>:17: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_i': trial.suggest_loguniform('reg_i', 1e-6, 1e-2)}
# [I 2024-05-22 06:16:14,060] Trial 7 finished with value: 0.9781813148918622 and parameters: {'algorithm': 'BaselineOnly', 'method': 'sgd', 'reg_u': 1.943496145163179e-06, 'reg_i': 0.0004035840731135454}. Best is trial 3 with value: 0.9681354247939034.
# [I 2024-05-22 06:16:16,363] Trial 8 finished with value: 1.0644125773861166 and parameters: {'algorithm': 'CoClustering', 'n_cltr_u': 6, 'n_cltr_i': 8}. Best is trial 3 with value: 0.9681354247939034.
# [I 2024-05-22 06:16:17,404] Trial 9 finished with value: 1.0930567074139177 and parameters: {'algorithm': 'KNNBasic', 'k': 31, 'min_k': 4, 'similarity': 'pearson', 'user_based': False}. Best is trial 3 with value: 0.9681354247939034.
# [I 2024-05-22 06:16:17,677] Trial 10 finished with value: 0.9474632789738126 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 0.0038690237570350476, 'reg_i': 2.315068645188416e-06}. Best is trial 10 with value: 0.9474632789738126.
# [I 2024-05-22 06:16:18,035] Trial 11 finished with value: 0.9483029676148371 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 0.006292021506456918, 'reg_i': 1.1508835045848626e-06}. Best is trial 10 with value: 0.9474632789738126.
# [I 2024-05-22 06:16:18,430] Trial 12 finished with value: 0.9448510287088688 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 0.006177947010978888, 'reg_i': 1.2280063929438247e-06}. Best is trial 12 with value: 0.9448510287088688.
# [I 2024-05-22 06:16:18,709] Trial 13 finished with value: 0.9496545838738193 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 0.007763633746669389, 'reg_i': 1.007200316994454e-06}. Best is trial 12 with value: 0.9448510287088688.
# [I 2024-05-22 06:16:19,077] Trial 14 finished with value: 0.9430099183403428 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 0.0004603178069507199, 'reg_i': 1.3198311690010226e-05}. Best is trial 14 with value: 0.9430099183403428.
# [I 2024-05-22 06:16:19,395] Trial 15 finished with value: 0.9509267257762004 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 0.00017118304850757127, 'reg_i': 3.419286337950953e-05}. Best is trial 14 with value: 0.9430099183403428.
# [I 2024-05-22 06:16:19,751] Trial 16 finished with value: 0.9466326984149757 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 0.00027620666396668256, 'reg_i': 3.0140311452353687e-05}. Best is trial 14 with value: 0.9430099183403428.
# [I 2024-05-22 06:16:20,255] Trial 17 finished with value: 0.9786029233030021 and parameters: {'algorithm': 'BaselineOnly', 'method': 'sgd', 'reg_u': 0.0007051523888652665, 'reg_i': 0.0064821006446181585}. Best is trial 14 with value: 0.9430099183403428.
# [I 2024-05-22 06:16:20,548] Trial 18 finished with value: 0.9439291305545292 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 1.3677169360197525e-05, 'reg_i': 9.678151019848278e-06}. Best is trial 14 with value: 0.9430099183403428.
# [I 2024-05-22 06:16:22,965] Trial 19 finished with value: 1.0410026522538398 and parameters: {'algorithm': 'CoClustering', 'n_cltr_u': 3, 'n_cltr_i': 3}. Best is trial 14 with value: 0.9430099183403428.
# [I 2024-05-22 06:16:23,432] Trial 20 finished with value: 0.9479079520460724 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 1.2398344105471285e-05, 'reg_i': 1.240670748257185e-05}. Best is trial 14 with value: 0.9430099183403428.
# [I 2024-05-22 06:16:24,022] Trial 21 finished with value: 0.9507849086575582 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 2.022500472784693e-05, 'reg_i': 6.668213752670268e-06}. Best is trial 14 with value: 0.9430099183403428.
# [I 2024-05-22 06:16:24,526] Trial 22 finished with value: 0.9488120145807227 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 2.9573588385742885e-05, 'reg_i': 0.0001699014775644394}. Best is trial 14 with value: 0.9430099183403428.
# [I 2024-05-22 06:16:24,904] Trial 23 finished with value: 0.951190123523172 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 0.0017959677417629049, 'reg_i': 5.81780441586442e-06}. Best is trial 14 with value: 0.9430099183403428.
# [I 2024-05-22 06:16:25,491] Trial 24 finished with value: 0.9796916793476611 and parameters: {'algorithm': 'BaselineOnly', 'method': 'sgd', 'reg_u': 2.4244356681744268e-06, 'reg_i': 3.42964166901998e-05}. Best is trial 14 with value: 0.9430099183403428.
# [I 2024-05-22 06:16:25,783] Trial 25 finished with value: 0.947051682894735 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 5.731185784135748e-05, 'reg_i': 6.873847621388916e-06}. Best is trial 14 with value: 0.9430099183403428.
# [I 2024-05-22 06:16:26,139] Trial 26 finished with value: 0.9485924036184444 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 0.000739936747791749, 'reg_i': 2.972492732638683e-06}. Best is trial 14 with value: 0.9430099183403428.
# [I 2024-05-22 06:16:28,664] Trial 27 finished with value: 1.0672401905573101 and parameters: {'algorithm': 'CoClustering', 'n_cltr_u': 10, 'n_cltr_i': 10}. Best is trial 14 with value: 0.9430099183403428.
# [I 2024-05-22 06:16:29,558] Trial 28 finished with value: 1.0109485665091487 and parameters: {'algorithm': 'KNNBasic', 'k': 10, 'min_k': 1, 'similarity': 'msd', 'user_based': False}. Best is trial 14 with value: 0.9430099183403428.
# [I 2024-05-22 06:16:33,995] Trial 29 finished with value: 1.1789654738562392 and parameters: {'algorithm': 'KNNBasic', 'k': 40, 'min_k': 10, 'similarity': 'cosine', 'user_based': True}. Best is trial 14 with value: 0.9430099183403428.
# [I 2024-05-22 06:16:34,296] Trial 30 finished with value: 0.9482540965486184 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 0.001289998405034166, 'reg_i': 8.895263925223403e-05}. Best is trial 14 with value: 0.9430099183403428.
# [I 2024-05-22 06:16:34,827] Trial 31 finished with value: 0.9528583866240372 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 0.00021960187781528914, 'reg_i': 2.000622161042837e-05}. Best is trial 14 with value: 0.9430099183403428.
# [I 2024-05-22 06:16:35,324] Trial 32 finished with value: 0.9405954164022274 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 0.0003496807372657765, 'reg_i': 7.80320983995176e-05}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:16:35,898] Trial 33 finished with value: 0.9454166411233742 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 7.440634660202728e-06, 'reg_i': 0.0005231450961028439}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:16:37,106] Trial 34 finished with value: 0.9816444223143711 and parameters: {'algorithm': 'SVD', 'n_factors': 53, 'n_epochs': 23}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:16:37,514] Trial 35 finished with value: 0.9474785954893382 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 7.372221848431679e-05, 'reg_i': 8.836267262762853e-05}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:16:40,289] Trial 36 finished with value: 0.9824908152090565 and parameters: {'algorithm': 'SVD', 'n_factors': 197, 'n_epochs': 51}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:16:40,581] Trial 37 finished with value: 0.9461013765625778 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 0.0003427439705005585, 'reg_i': 2.494718273427921e-06}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:16:42,946] Trial 38 finished with value: 0.969357488591489 and parameters: {'algorithm': 'SVD', 'n_factors': 83, 'n_epochs': 73}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:16:43,817] Trial 39 finished with value: 1.0046879263776112 and parameters: {'algorithm': 'KNNBasic', 'k': 20, 'min_k': 2, 'similarity': 'msd', 'user_based': False}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:16:45,830] Trial 40 finished with value: 1.0412491737235738 and parameters: {'algorithm': 'CoClustering', 'n_cltr_u': 3, 'n_cltr_i': 3}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:16:46,119] Trial 41 finished with value: 0.9562194859038021 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 2.204187542558703e-05, 'reg_i': 0.0012344005697823394}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:16:46,504] Trial 42 finished with value: 0.950790370451856 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 7.420317639094011e-06, 'reg_i': 0.000537369217140883}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:16:46,809] Trial 43 finished with value: 0.9526678645374758 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 5.162224458065574e-06, 'reg_i': 0.001740415065424397}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:16:47,271] Trial 44 finished with value: 0.9497534419575869 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 4.449084172307844e-06, 'reg_i': 0.00028470472813676783}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:16:48,073] Trial 45 finished with value: 0.9812517046820924 and parameters: {'algorithm': 'BaselineOnly', 'method': 'sgd', 'reg_u': 0.0028221163521680486, 'reg_i': 7.275437991187944e-05}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:16:48,564] Trial 46 finished with value: 0.947588595475267 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 1.14492776423259e-06, 'reg_i': 1.7234174870096727e-05}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:16:49,212] Trial 47 finished with value: 0.9475449391266078 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 0.0005445808099825176, 'reg_i': 0.0008306130254799011}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:16:52,634] Trial 48 finished with value: 0.9662127677639697 and parameters: {'algorithm': 'SVD', 'n_factors': 99, 'n_epochs': 98}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:16:52,993] Trial 49 finished with value: 0.9475723421273153 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 9.631427966996376e-05, 'reg_i': 0.0025538528169195816}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:16:55,435] Trial 50 finished with value: 1.0504857851937583 and parameters: {'algorithm': 'CoClustering', 'n_cltr_u': 7, 'n_cltr_i': 6}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:16:55,732] Trial 51 finished with value: 0.9505303558343092 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 0.0003850970401477415, 'reg_i': 3.1718333414197565e-06}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:16:56,242] Trial 52 finished with value: 0.9769824432251778 and parameters: {'algorithm': 'BaselineOnly', 'method': 'sgd', 'reg_u': 0.00012803355783450388, 'reg_i': 1.7002994859706474e-06}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:16:56,536] Trial 53 finished with value: 0.9513288435001636 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 4.246690090943396e-05, 'reg_i': 4.375461209089383e-06}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:16:56,899] Trial 54 finished with value: 0.9488754549893468 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 0.0014785092647685422, 'reg_i': 1.7382203171254223e-06}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:16:57,220] Trial 55 finished with value: 0.9497448990008603 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 0.00033875613442281544, 'reg_i': 1.0748753079721978e-05}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:16:57,593] Trial 56 finished with value: 0.9474773162218705 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 0.00453477458294949, 'reg_i': 0.00022308457098825846}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:16:58,603] Trial 57 finished with value: 1.064971589737298 and parameters: {'algorithm': 'KNNBasic', 'k': 40, 'min_k': 5, 'similarity': 'cosine', 'user_based': False}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:16:58,970] Trial 58 finished with value: 0.9495334873374947 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 0.009217998706164708, 'reg_i': 1.3069124740296837e-06}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:16:59,352] Trial 59 finished with value: 0.9434836791285036 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 1.038667778633204e-05, 'reg_i': 2.6141522108832927e-06}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:16:59,865] Trial 60 finished with value: 0.9792022353562144 and parameters: {'algorithm': 'BaselineOnly', 'method': 'sgd', 'reg_u': 1.0311229068608308e-05, 'reg_i': 3.959501345319293e-05}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:17:00,457] Trial 61 finished with value: 0.9473241686722131 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 1.4027411392948189e-05, 'reg_i': 2.066663960019257e-06}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:17:00,901] Trial 62 finished with value: 0.9519378710052412 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 5.513527507684467e-06, 'reg_i': 3.881092241177587e-06}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:17:01,521] Trial 63 finished with value: 0.9520476627105264 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 0.00015706871114873778, 'reg_i': 1.0479559775565972e-06}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:17:02,046] Trial 64 finished with value: 0.941726529452224 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 2.9478829775880443e-06, 'reg_i': 8.49457309122502e-06}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:17:02,551] Trial 65 finished with value: 0.9536650748986323 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 2.730818056773095e-06, 'reg_i': 8.481159431013075e-06}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:17:04,933] Trial 66 finished with value: 1.0539836036313972 and parameters: {'algorithm': 'CoClustering', 'n_cltr_u': 6, 'n_cltr_i': 10}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:17:05,238] Trial 67 finished with value: 0.9425711318368221 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 1.5400842109083249e-06, 'reg_i': 1.661620037596883e-05}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:17:05,649] Trial 68 finished with value: 0.9554268690796186 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 1.130390874095367e-06, 'reg_i': 1.3682681055200077e-05}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:17:11,349] Trial 69 finished with value: 1.1870878752261709 and parameters: {'algorithm': 'KNNBasic', 'k': 11, 'min_k': 7, 'similarity': 'pearson', 'user_based': True}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:17:11,748] Trial 70 finished with value: 0.9452074258079343 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 1.5904001011211288e-06, 'reg_i': 5.7016399472848386e-05}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:17:12,029] Trial 71 finished with value: 0.9448289294544304 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 1.91951943978552e-06, 'reg_i': 4.123961676456634e-05}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:17:12,549] Trial 72 finished with value: 0.9552260942475052 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 3.099642052445382e-06, 'reg_i': 2.1350989096027894e-05}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:17:13,155] Trial 73 finished with value: 0.9467252273131868 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 2.044015288311193e-06, 'reg_i': 2.6761877610928865e-05}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:17:13,620] Trial 74 finished with value: 0.94718655948764 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 3.541432822530267e-06, 'reg_i': 9.424156414313876e-06}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:17:15,879] Trial 75 finished with value: 0.9822819321257356 and parameters: {'algorithm': 'SVD', 'n_factors': 166, 'n_epochs': 35}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:17:16,169] Trial 76 finished with value: 0.9453974282698088 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 1.543413672610057e-06, 'reg_i': 4.774678116591145e-06}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:17:16,548] Trial 77 finished with value: 0.950980393609031 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 3.559638894665247e-05, 'reg_i': 0.00013394242157646754}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:17:16,941] Trial 78 finished with value: 0.9783731163757389 and parameters: {'algorithm': 'BaselineOnly', 'method': 'sgd', 'reg_u': 0.0008114143058394357, 'reg_i': 4.797191434349421e-05}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:17:17,316] Trial 79 finished with value: 0.9449878079780295 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 1.0042791908498177e-06, 'reg_i': 1.4284908715245747e-05}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:17:20,112] Trial 80 finished with value: 1.0609859251010918 and parameters: {'algorithm': 'CoClustering', 'n_cltr_u': 8, 'n_cltr_i': 8}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:17:20,415] Trial 81 finished with value: 0.9476497745041371 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 1.1304333940124516e-06, 'reg_i': 1.4773009918304446e-05}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:17:20,966] Trial 82 finished with value: 0.950908877284751 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 2.1857055328719745e-06, 'reg_i': 2.3663373461801642e-05}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:17:21,253] Trial 83 finished with value: 0.9463501357508209 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 3.2021985345069878e-06, 'reg_i': 7.449933382233175e-06}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:17:21,636] Trial 84 finished with value: 0.9444267063185965 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 1.61183971404949e-06, 'reg_i': 1.2285510596404215e-05}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:17:21,923] Trial 85 finished with value: 0.9491742207372326 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 1.7356263846898664e-06, 'reg_i': 3.183280145850221e-05}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:17:22,276] Trial 86 finished with value: 0.9467303580792766 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 0.0022963699983763264, 'reg_i': 5.0536782370064655e-06}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:17:26,022] Trial 87 finished with value: 1.098541620085722 and parameters: {'algorithm': 'KNNBasic', 'k': 31, 'min_k': 3, 'similarity': 'msd', 'user_based': True}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:17:29,138] Trial 88 finished with value: 0.9684832715473942 and parameters: {'algorithm': 'SVD', 'n_factors': 110, 'n_epochs': 69}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:17:29,556] Trial 89 finished with value: 0.943083740548255 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 2.105420090253909e-05, 'reg_i': 1.1273390733267385e-05}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:17:29,865] Trial 90 finished with value: 0.9466843247792793 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 2.2371453944769554e-05, 'reg_i': 1.1999974909623921e-05}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:17:30,236] Trial 91 finished with value: 0.9481633552846382 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 1.2148512537228836e-05, 'reg_i': 6.203346867992766e-06}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:17:30,539] Trial 92 finished with value: 0.9487306064758387 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 0.005580096660267414, 'reg_i': 9.901578810632337e-06}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:17:30,908] Trial 93 finished with value: 0.9495648824592114 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 1.7969088038075196e-05, 'reg_i': 1.907830271338701e-05}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:17:31,279] Trial 94 finished with value: 0.9510953976925668 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 9.292882262529047e-06, 'reg_i': 0.00011203911917889503}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:17:31,581] Trial 95 finished with value: 0.9502158593658011 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 6.854455745306924e-06, 'reg_i': 5.9118421423821816e-05}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:17:31,946] Trial 96 finished with value: 0.9461835427334919 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 4.572960323237518e-05, 'reg_i': 3.0240781742097074e-06}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:17:32,245] Trial 97 finished with value: 0.9481597077227141 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 3.7239302250414202e-06, 'reg_i': 7.0286357385882514e-06}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:17:32,750] Trial 98 finished with value: 0.9802124761561842 and parameters: {'algorithm': 'BaselineOnly', 'method': 'sgd', 'reg_u': 7.831275800522996e-05, 'reg_i': 4.339498528504163e-05}. Best is trial 32 with value: 0.9405954164022274.
# [I 2024-05-22 06:17:33,056] Trial 99 finished with value: 0.9464488042953327 and parameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 1.4756645180278506e-06, 'reg_i': 1.484579142766863e-06}. Best is trial 32 with value: 0.9405954164022274.

# %%
best_params = study.best_params
print("Best Hyperparameters:", best_params)
# Out:
# Best Hyperparameters: {'algorithm': 'BaselineOnly', 'method': 'als', 'reg_u': 0.0003496807372657765, 'reg_i': 7.80320983995176e-05}
