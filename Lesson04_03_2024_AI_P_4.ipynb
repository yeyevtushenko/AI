# %% [markdown]
# <a href="https://colab.research.google.com/github/yeyevtushenko/AI/blob/Lesson04.03.2024/Lesson04_03_2024_AI_P_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/HalyshAnton/IT-Step-Pyton-AI/main/module2/data/weatherHistory.csv")

# %%
df.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %% [markdown]
# # Завдання 1
# Виведіть основні числові характеристики для числових ознак. Що потрібно зробити з стовпчиком `Loud Cover`?

# %%
df.info()
df.describe(include="number")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  float64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  float64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Summary             96453 non-null  object
# dtypes: float64(8), object(4)
# memory usage: 8.8+ MB
# ...

# %%
df["Loud Cover"].unique()
# Out:
# array([0.])

# %%
df.drop(columns=["Loud Cover"], inplace=True)

# %%
df.shape
# Out:
# (96453, 11)

# %% [markdown]
# # Завдання 2
# Подивіться на отриману таблицю, особливо на характеристики `min` та `max`, для яких ознак потрібно побудувати ящики з вусами в першу чергу? Для решти намалюйте гістограми.

# %%
df["Pressure (millibars)"].plot(kind="box", vert=False, figsize=(14,6))
# Out:
# <Axes: >

# %%
plt.title("Temperature (C)")
df["Temperature (C)"].plot(kind="hist", bins=50, figsize=(14,6))
# Out:
# <Axes: title={'center': 'Temperature (C)'}, ylabel='Frequency'>

# %%
plt.title("Apparent Temperature (C)")
df["Apparent Temperature (C)"].plot(kind="hist", bins=50, figsize=(14,6))
# Out:
# <Axes: title={'center': 'Apparent Temperature (C)'}, ylabel='Frequency'>

# %%
plt.title("Humidity")
df["Humidity"].plot(kind="hist", bins=50, figsize=(14,6))
# Out:
# <Axes: title={'center': 'Humidity'}, ylabel='Frequency'>

# %%
plt.title("Wind Speed (km/h)")
df["Wind Speed (km/h)"].plot(kind="hist", bins=50, figsize=(14,6))
# Out:
# <Axes: title={'center': 'Wind Speed (km/h)'}, ylabel='Frequency'>

# %%
plt.title("Wind Bearing (degrees)")
df["Wind Bearing (degrees)"].plot(kind="hist", bins=50, figsize=(14,6))
# Out:
# <Axes: title={'center': 'Wind Bearing (degrees)'}, ylabel='Frequency'>

# %%
plt.title("Visibility (km)")
df["Visibility (km)"].plot(kind="hist", bins=50, figsize=(14,6))
# Out:
# <Axes: title={'center': 'Visibility (km)'}, ylabel='Frequency'>

# %% [markdown]
# # Завдання 3
# Чи потрібно застосувати квантильний алгоритм для видалення викидів? Якщо так то застосуйте, інакше, що на вашу думку потрібно зробити?

# %%
def outliers(df, column_name):
  column = df[column_name]

  Q1 = column.quantile(q=0.25)
  Q3 = column.quantile(q=0.75)

  IQR = Q3 - Q1

  lower = Q1 - 1.5*IQR
  upper = Q3 + 1.5*IQR

  mask = (column >= lower) & (column <= upper)

  return df[mask]

for column_name in df.columns:
  if df.dtypes[column_name] in ("object", "datetime64[ns]"):
    continue

  df = outliers(df, column_name)

# %%
df.shape
# Out:
# (89174, 11)

# %% [markdown]
# # Завдання 4
# Намалюйте матрицю кореляцій. Для найбільш корельованих ознак намалюйте точкову діаграму

# %%
corr = df.corr(method='pearson')

fig = plt.figure(figsize=(8,8))
plt.matshow(corr, cmap='RdBu', fignum=fig.number)

plt.xticks(range(len(corr.columns)), corr.columns, rotation='vertical')
plt.yticks(range(len(corr.columns)), corr.columns)
plt.colorbar()
# Out:
# <ipython-input-20-f8274ddceb01>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr(method='pearson')

# %%
df.plot(kind='scatter', x="Temperature (C)", y="Humidity", figsize=(6,6))
# Out:
# <Axes: xlabel='Temperature (C)', ylabel='Humidity'>

# %%
df.plot(kind='scatter', x="Temperature (C)", y="Apparent Temperature (C)", figsize=(6,6))
# Out:
# <Axes: xlabel='Temperature (C)', ylabel='Apparent Temperature (C)'>

# %%
df.plot(kind='scatter', x="Visibility (km)", y="Humidity", figsize=(6,6))
# Out:
# <Axes: xlabel='Visibility (km)', ylabel='Humidity'>

# %% [markdown]
# # Завдання 5
# Виведіть характеристики для категоріальних ознак

# %%
df.describe(include="object")
# Out:
#                        Formatted Date        Summary Precip Type  \
# count                           89174          89174       88679
# unique                          89150             14           2
# top     2010-08-02 14:00:00.000 +0200  Partly Cloudy        rain
# freq                                2          30829       79733
#
#                             Daily Summary
# count                               89174
# unique                                212
# top     Mostly cloudy throughout the day.
# freq                                19242

# %% [markdown]
# # Завдання 6
# Виведіть групові ящики з вусами по одній(або декількох) категоріальних ознак. Що по них можна сказати?

# %%
col = df.select_dtypes(include='number').columns
for column_name in col:
  df[[column_name, 'Summary']].boxplot(by='Summary', figsize=(40, 10))
  plt.show()
